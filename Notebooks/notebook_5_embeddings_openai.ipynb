# %% [markdown]
# # Uso de modelos de embeddings de OpenAI

# %% [markdown]
# ## Instalación y carga de librerías

# %%
# !pip install openai
# !pip install tiktoken
# Out:
# Collecting openai
#   Downloading openai-1.69.0-py3-none-any.whl (599 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 KB 7.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>4 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from openai) (4.12.2)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.9/352.9 KB 6.9 MB/s eta 0:00:00a 0:00:01
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 KB 5.9 MB/s eta 0:00:00
# Collecting httpx<1,>=0.23.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.11.0-py3-none-any.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 KB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: idna>=2.8 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Requirement already satisfied: certifi in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Collecting pydantic-core==2.33.0
#   Downloading pydantic_core-2.33.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, jiter, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.9.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 jiter-0.9.0 openai-1.69.0 pydantic-2.11.0 pydantic-core-2.33.0 sniffio-1.3.1 typing-inspection-0.4.0
# Collecting tiktoken
#   Using cached tiktoken-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Requirement already satisfied: regex>=2022.1.18 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/c/users/daniel.cardenas/Documents/Daniel_documents/Platzi/Curso_de_Embeddings_y_Bases_de_Datos_Vectoriales_para_NLP/venv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.9.0

# %%
from openai import OpenAI
import os
import pandas as pd
from tqdm import tqdm

tqdm.pandas()

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
client_openai = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# ## Cargar dataset

# %%
df = pd.read_csv('generic-food.csv')

# %%
df.head()
# Out:
#         FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 0        Angelica                Angelica keiskei  Herbs and Spices
# 1   Savoy cabbage  Brassica oleracea var. sabauda        Vegetables
# 2   Silver linden                  Tilia argentea  Herbs and Spices
# 3            Kiwi             Actinidia chinensis            Fruits
# 4  Allium (Onion)                          Allium        Vegetables
#
#                  SUB GROUP
# 0                    Herbs
# 1                 Cabbages
# 2                    Herbs
# 3          Tropical fruits
# 4  Onion-family vegetables

# %% [markdown]
# ## Evaluar cantidad de tokens a procesar

# %%
import tiktoken

def num_tokens_from_string(text, encodig_name):
    encoding = tiktoken.get_encoding(encodig_name)
    num_tokens = len(encoding.encode(text))
    return num_tokens

# %%
df['total_tokens'] = df['FOOD NAME'].apply(lambda x : num_tokens_from_string(x,'cl100k_base') )

# %%
sum(df['total_tokens'])
# Out:
# 2947

# %% [markdown]
# ## Generando emebeddings

# %%
def get_embedding(text, model = "text-embedding-ada-002"):
  text = text.replace('\n', '')
  response = client_openai.embeddings.create(
      input=text,
      model=model
  )
  return response.data[0].embedding

# %%
df['ada_embeddings'] =  df['FOOD NAME'].progress_apply(lambda x :get_embedding(x) )
# Out:
#   0%|          | 0/906 [00:00<?, ?it/s]
# 100%|██████████| 906/906 [05:19<00:00,  2.83it/s]

# %%
df.head()
# Out:
#         FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 0        Angelica                Angelica keiskei  Herbs and Spices
# 1   Savoy cabbage  Brassica oleracea var. sabauda        Vegetables
# 2   Silver linden                  Tilia argentea  Herbs and Spices
# 3            Kiwi             Actinidia chinensis            Fruits
# 4  Allium (Onion)                          Allium        Vegetables
#
#                  SUB GROUP  total_tokens  \
# 0                    Herbs             2
# 1                 Cabbages             4
# 2                    Herbs             3
# 3          Tropical fruits             2
# 4  Onion-family vegetables             6
#
#                                       ada_embeddings
# 0  [0.006170166190713644, -0.010142647661268711, ...
# 1  [0.005480199586600065, -0.00497033866122365, 0...
# 2  [-0.004524254705756903, 0.020042214542627335, ...
# 3  [-0.004660817328840494, -0.010033704340457916,...
# 4  [0.013233134523034096, -0.01992831565439701, 0...

# %%
embedding_prueba = get_embedding('esto es una prueba de embeddings para openAI')

# %%
len(embedding_prueba)
# Out:
# 1536

# %% [markdown]
# ## Creando datasets para visualizar

# %%
df_embeddings = pd.DataFrame(list(df['ada_embeddings']))

# %%
df_embeddings.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.006170 -0.010143  0.004632 -0.028876 -0.005418  0.013093 -0.016356
# 1  0.005480 -0.004970  0.014879 -0.010877 -0.002445  0.021254 -0.008902
# 2 -0.004524  0.020042 -0.002014 -0.024094 -0.016662  0.020498 -0.041319
# 3 -0.004661 -0.010034 -0.009140 -0.010014 -0.007865  0.023123 -0.014410
# 4  0.013233 -0.019928  0.002172 -0.010036 -0.018671  0.022313 -0.018094
#
#        7         8         9     ...      1526      1527      1528      1529  \
# 0  0.007352 -0.010089 -0.028104  ...  0.024281 -0.011475  0.004445 -0.022603
# 1 -0.024307 -0.018034 -0.039711  ...  0.017996 -0.019817  0.026833 -0.032631
# 2 -0.001910 -0.001223 -0.035416  ...  0.002936 -0.022309  0.038609 -0.026388
# 3 -0.016287 -0.001691 -0.036354  ...  0.030994 -0.012144  0.022424 -0.011930
# 4 -0.015277 -0.008759 -0.020544  ...  0.020138 -0.034537  0.031655 -0.010980
#
#        1530      1531      1532      1533      1534      1535
# 0 -0.008817  0.031007  0.008318 -0.004019 -0.022590 -0.015104
# 1 -0.019509  0.020035 -0.025666  0.010473 -0.007734  0.000761
# 2 -0.032438  0.021142 -0.000291 -0.020525 -0.011577 -0.033457
# 3 -0.005402  0.010668 -0.021854 -0.001701 -0.014060 -0.020715
# 4 -0.019339  0.000338  0.010279  0.001162 -0.001145  0.012421
#
# [5 rows x 1536 columns]

# %%
df_embeddings.to_csv('embedding_food.tsv',sep='\t',index=False, header=False)

# %%
df[['FOOD NAME','GROUP','SUB GROUP']].to_csv('labels_food.tsv',sep='\t',index=False, header=True)
